# %% [markdown]
# <a href="https://colab.research.google.com/github/lrfrancof/INTEGRADOR-RICHI/blob/main/PROYECTO_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Matricula:A00832808
# Nombre:Luis Ricardo Franco
# Link:https://colab.research.google.com/drive/1Luyy4U8um4amXDVeBOmNBCMtOP1MvRxm?usp=sharing

# %%
main()
# Out:
# Empleados:9
#
# [['2', 'tu', '50', '90', '1.7', '1', '1', '1', '1', '1', '1', '1'], ['1', 'tu', '50', '90', '1.7', '1', '1', '1', '1', '1', '1', '1'], ['3', 'tu', '50', '90', '1.7', '1', '1', '1', '1', '1', '1', '1'], ['5', 'tu', '50', '90', '1.7', '1', '1', '1', '1', '1', '1', '1'], ['6', 'tu', '50', '90', '1.7', '1', '1', '1', '1', '1', '1', '1'], ['7', 'tu', '50', '90', '1.7', '1', '1', '1', '1', '1', '1', '1'], ['8', 'tu', '50', '90', '1.7', '1', '1', '1', '1', '1', '1', '1'], ['98', 'LOPEZ', '87', '76', '1.87', '2', '2', '2', '2', '2', '1', '4'], ['4', 'Ellos', '43', '98', '1.82', '2', '2', '2', '2', '2', '2', '2']]
# Bienvenido a el Menú
# 1.-Alta de Empleado
# 2.-Calcular IMC
# 3.-Cambiar información del empleado
# 4.-Consulta un empleado
# 5.-Reporte de todos los empleados
# 6.-Salir
# Empleados:9
#
# Ingrese lo deseado: 2
# Empleados:9
#
# Clasificación   IMC   ID    Nombre  	Peso	Altura
# ...

# %%
def men():
    print("Bienvenido a el Menú")
    print("1.-Alta de Empleado")
    print("2.-Calcular IMC")
    print("3.-Cambiar información del empleado")
    print("4.-Consulta un empleado")
    print("5.-Reporte de todos los empleados")
    print("6.-Salir")

# %%
def loadEmpleados(): #Función para cargar la lista de empleados
  #print(pathlib.Path().resolve())
  if (exists("empleados2.txt")!=True):#En el caso que no exista el archivo(si no se descargo y se subio en colab) te permite inicar tu lista de empleados desde 0
    return []

  with open ("empleados2.txt", "r") as myfile: #Se abre el archivo en modo "R" que significa leer.
   data=myfile.readlines()
  empleados = []
  for line in data:
    empleados.append(line.split(',')) #Se agrega la coma entre cada dato, para poder acceder a los datos especificamente.

  for empleado in empleados:
    empleado.pop()#Elimina un valor invisible que se crea al final de la lista.
  
  print ("Empleados:" + str(len(empleados)) + "\n")
  print(empleados)
  return empleados

# %%
from os.path import exists
import pathlib # importa "exists".

# %%
def empleado(): #Función que reacuda los datos de cada empleado
 lista = []#se crea una lista sin datos.
 id=(input("ID: "))#Pide al empleado ingesar sus datos
 lista.append(id)
 name=input("Nombre: ")
 lista.append(name)#Se guardan los datos con "Append" en la lista.
 edad=(input("Edad: "))
 lista.append(edad)
 peso=(input("Ingrese Peso(Kg): "))
 lista.append(peso)
 estatura=(input("Ingrese Estatura(mts): "))
 lista.append(estatura)
 diabe=(input("Diabetes: 1.-Si 2.-No: "))
 lista.append(diabe)
 hiper=(input("Hipertensión: 1.-Si 2.-No: "))
 lista.append(hiper)
 cora=(input("Problema de Corazón: 1.-Si 2.-No: "))
 lista.append(cora)
 cancer=(input("Cancer: 1.-Si 2.-No: "))
 lista.append(cancer)
 tabaquismo=(input("Tabaquismo: 1.-Si 2.-No: "))
 lista.append(tabaquismo)
 vacuna=(input("Vacuna Covid: 1.-Si 2.-No: "))
 lista.append(vacuna)
 departam=(input("No de Departamento: "))
 lista.append(departam)
 print(lista) #Se imprime la lista entera al finalizar.
 
 archivo = open("empleados2.txt", "a") #Se abre el archivo en modo "Append".

  
 for palabra in lista:
    archivo.write(str(palabra) + ",") #Para cada palabra en la ,lista, se vuelven strings separados por comas.
    
  
 archivo.write("\n") #Salto de linea
 archivo.close()

# %%
def main(): #Funcion principal del programa
  #open('empleados2.txt', 'w').close()
  empleados = []
  empleados =loadEmpleados()
  
  valor= 0  #Se asgina un valor 0
  while valor != 6: #Mientras el valor sea diferente a 7 se repite y abre el menú.
    
    men()
    print ("Empleados:" + str(len(empleados)) + "\n")#Indica el número de empleados
    valor= int(input("Ingrese lo deseado: ")) #Ingresas un número del 1-7, dependiendo de lo que gustes.

    if valor == 1 : #If para que cuando escribas "1", se ejecute una función especifica.
        empleado()
        empleados =loadEmpleados()
    if valor == 2:
            imc(empleados)
            
    if valor == 3:
            cambiardatos(empleados)
            empleados =loadEmpleados()
    
    if valor == 4:
            consultar_empleado(empleados)
            empleados =loadEmpleados()
            

    if valor ==5:
            reporteempleados5(empleados)
        
    

    if valor == 6:  #Cuando se quiera salir, te manda un mensaje de despedida y se cierra el programa, gracias al while del principio.
            print("Muchas gracias, vuelva pronto")

    if valor >=7:
            print("ERROR") #Si no es de los valores solicitados, marca error y vuelve a preguntar.

# %%
def diagnosticoimc(imc): #Funcion que indica el IMC y informacion al respecto.
 
  if imc < 16:  
    delsevera = delsevera + 1
    return "Delgadez Severa"
  if imc >=16 and imc <=16.99:
    delmoderada= delmoderada + 1
    return "Delgadez Moderada"
  if imc >=17 and imc <=18.49:
    delaceptable = delaceptable + 1
    return "Delgadez aceptable"
  if imc >=18.5 and imc <=24.99:
    normal = normal + 1
    return "Normal"
  if imc >=25 and imc <=30:
    sobrepeso = sobrepeso + 1
    return "Sobrepeso"
  if imc >=30 and imc <=34.99:
    obeso1= obeso1 + 1
    return "Obeso Tipo I"
  if imc >=35 and imc <=39.99:
    obeso2= obeso2 + 1
    return "Obeso tipo II"
  if imc >=40:
    obeso3= obeso3 + 1
    return "Obeso Tipo III"
  
  print(listaporcentajes)

# %%
def reporteempleados5(empleados):
  archivo = (input("Indique el nombre del archivo"))
  if (exists(archivo)!=True):
    open(archivo, 'w').close()

  
  archivo = open(archivo, "w")

  delsevera= 0
  delmoderada= 0
  delaceptable= 0
  normal= 0
  sobrepeso = 0 #Contadores
  obeso1= 0
  obeso2 = 0
  obeso3 = 0

  diabetes= 0
  hipertension= 0
  corazon= 0
  cancer= 0
  tabaquismo = 0 #Contadores
  vacuna_covid= 0

  #archivo.write(str(palabra) + ",")
  archivo.write ("Empleados:" + str(len(empleados)) + "\n") 
  archivo.write("Clasificación   " + "IMC  "+ " ID  "+ "  Nombre  "+ "\t"+ "Peso"+ "\t" + "Altura\n" )

  for lista in empleados:
    peso  = float(lista[3]) #Valor 3 de la lista se vuelve en peso.
    estatura = float(lista[4]) #Valor 4 de la lista se vuelve altura.
    imc = round(peso/(estatura*estatura),2) #Formula para obtener IMC
    archivo.write(imprimeempleado(lista) + "\n")
    if imc < 16:    #Si el imc entra en una categoria, se suma al contador, para llevar el registro.
      delsevera = delsevera + 1
      
    if imc >=16 and imc <=16.99:
      delmoderada= delmoderada + 1
      
    if imc >=17 and imc <=18.49:
      delaceptable = delaceptable + 1
      
    if imc >=18.5 and imc <=24.99:
      normal = normal + 1
      
    if imc >=25 and imc <=30:
      sobrepeso = sobrepeso + 1
      
    if imc >=30 and imc <=34.99:
      obeso1= obeso1 + 1
      
    if imc >=35 and imc <=39.99:
      obeso2= obeso2 + 1
      
    if imc >=40:
      obeso3= obeso3 + 1

    if (lista[5]=="1"):
        diabetes = diabetes + 1
    if (lista[6]=="1"):
        hipertension = hipertension + 1
    if (lista[7]=="1"):
        corazon = corazon + 1
    if (lista[8]=="1"):
        cancer = cancer + 1
    if (lista[9]=="1"):
        tabaquismo = tabaquismo + 1
    if (lista[10]=="1"):
        vacuna_covid = vacuna_covid + 1


    
    
  archivo.write("Diagnostico" + "\t\t" + "Cantidad" + "\t"  + "Porcentaje " + "\t\n" )
  #archivo.write("Delgadez Moderada:" + "\t\t" + str(delmoderada) + "\t" + str((delmoderada*100)/len(empleados))+ "%\n") #Con tabs se separan los datos
  #archivo.write("Delgadez Severa:"+ "\t\t" + str(delsevera) + "\t" + str((delsevera*100)/len(empleados))+ "%\n") #           y se vuelve porcentaje.
  #archivo.write("Delgadez Aceptable:"+ "\t\t" + str(delaceptable) + "\t" + str((delaceptable*100)/len(empleados))+ "%\n")
  #archivo.write("            Normal:"+ "\t\t" + str(normal) + "\t" + str((normal*100)/len(empleados))+ "%\n")
  #archivo.write("         Sobrepeso:"+ "\t\t" + str(sobrepeso) + "\t" + str((sobrepeso*100)/len(empleados))+ "%\n")
  #archivo.write("          Obeso I"+ "\t\t" + str(obeso1) + "\t" + str((obeso1*100)/len(empleados))+ "%\n")
  #archivo.write("          Obeso II:"+ "\t\t" + str(obeso2) + "\t" + str((obeso2*100)/len(empleados))+ "%\n")
  #archivo.write("          Obeso III:"+ "\t\t" + str(obeso3) + "\t" + str((obeso3*100)/len(empleados))+ "%\n")

  archivo.write("Diabetes: " + str(diabetes)) + str((diabetes*100)/len(empleados))+ "%\n"
  archivo.write("Hipertensión: " + str(hipertension)) + str((hipertension*100)/len(empleados))+ "%\n"
  archivo.write("Cancer: " + str(cancer)) + str((cancer*100)/len(empleados))+ "%\n"
  archivo.write("Corazón: " + str(corazon)) + str((hipertension*100)/len(empleados))+ "%\n"
  archivo.write("Tabaquismo: " + str(tabaquismo)) + str((diabetes*100)/len(empleados))+ "%\n"
  archivo.write("Vacuna: " + str(vacuna_covid)) + str((hipertension*100)/len(empleados)+ "%\n"
  #
  #archivo.write("\n")
  archivo.close()
# Out:
#   File "<ipython-input-134-bbe27066b661>", line 92
#     archivo.close()
#           ^
# SyntaxError: invalid syntax

# %%
def imc(empleados): #Funcion que indica el IMC y informacion al respecto sobre los empleados.
  delsevera= 0
  delmoderada= 0
  delaceptable= 0
  normal= 0
  sobrepeso = 0 #Contadores
  obeso1= 0
  obeso2 = 0
  obeso3 = 0
  
  clasificacion=0
  etiqueta = ["Delgadez severa", "Delgadez moderada", "Delgadez aceptable", "Normal", "Pre-obeso", "Obeso tipo I", "Obeso tipo II", "Obeso tipo III"]
  print ("Empleados:" + str(len(empleados)) + "\n") 
  print("Clasificación   " + "IMC  "+ " ID  "+ "  Nombre  "+ "\t"+ "Peso"+ "\t" + "Altura" )
  for lista in empleados:
    peso  = float(lista[3]) #Valor 3 de la lista se vuelve en peso.
    estatura = float(lista[4]) #Valor 4 de la lista se vuelve altura.
    imc = round(peso/(estatura*estatura),2) #Formula para obtener IMC
    id=(lista[0])
    if imc < 16:    #Si el imc entra en una categoria, se suma al contador, para llevar el registro.
      delsevera = delsevera + 1
      clasificacion = etiqueta[0]
      
    if imc >=16 and imc <=16.99:
      delmoderada= delmoderada + 1
      clasificacion= etiqueta[1]
      
    if imc >=17 and imc <=18.49:
      delaceptable = delaceptable + 1
      clasificacion = etiqueta[2]
    if imc >=18.5 and imc <=24.99:
      normal = normal + 1
      clasificacion = etiqueta[3]
      
    if imc >=25 and imc <=30:
      sobrepeso = sobrepeso + 1
      clasificacion = etiqueta[4]
    if imc >=30 and imc <=34.99:
      obeso1= obeso1 + 1
      clasificacion = etiqueta[5]
      
    if imc >=35 and imc <=39.99:
      obeso2= obeso2 + 1
      clasificacion = etiqueta[6]
      
    if imc >=40:
      obeso3= obeso3 + 1
      clasificacion = etiqueta[7]
    diagnostico = clasificacion + "\t" + str(imc) + "\t" + str(id) + "\t" + str(peso) + "\t" + str(estatura) + "\t" 


    if lista[5]=="1":
        diagnostico = diagnostico + "\tDiabetes"
    else:
      diagnostico = diagnostico  + "\t--------"

    if lista[6]=="1":
        diagnostico = diagnostico + "\tHipertension"
    else:
      diagnostico = diagnostico  + "\t--------"
    if lista[7]=="1":
        diagnostico = diagnostico + "\tCorazón"
    else:
        diagnostico = diagnostico  + "\t--------"
    if lista[8]=="1":
        diagnostico = diagnostico + "\tCáncer"
        
    else:
      diagnostico = diagnostico  + "\t--------"
    if lista[9]=="1":
        diagnostico = diagnostico + "\tTabaquismo"
    else:
      diagnostico = diagnostico  + "\t--------"
    if lista[9]=="1":
        diagnostico = diagnostico + "\tCon Vacuna"
    else:
      diagnostico = diagnostico  + "\t--------"
    print(diagnostico)
  
    
  print("Diagnostico" + "\t\t" + "Cantidad" + "\t"  + "Porcentaje " + "\t" )
  print("Delgadez Moderada:" + "\t\t" + str(delmoderada) + "\t" + str((delmoderada*100)/len(empleados))+ "%") #Con tabs se separan los datos
  print("Delgadez Severa:"+ "\t\t" + str(delsevera) + "\t" + str((delsevera*100)/len(empleados))+ "%") #           y se vuelve porcentaje.
  print("Delgadez Aceptable:"+ "\t\t" + str(delaceptable) + "\t" + str((delaceptable*100)/len(empleados))+ "%")
  print("            Normal:"+ "\t\t" + str(normal) + "\t" + str((normal*100)/len(empleados))+ "%")
  print("         Sobrepeso:"+ "\t\t" + str(sobrepeso) + "\t" + str((sobrepeso*100)/len(empleados))+ "%")
  print("          Obeso I"+ "\t\t" + str(obeso1) + "\t" + str((obeso1*100)/len(empleados))+ "%")
  print("          Obeso II:"+ "\t\t" + str(obeso2) + "\t" + str((obeso2*100)/len(empleados))+ "%")
  print("          Obeso III:"+ "\t\t" + str(obeso3) + "\t" + str((obeso3*100)/len(empleados))+ "%")

# %%
def imprimeempleado2(lista):
    peso  = float(lista[3])
    estatura = float(lista[4])
    nombre = lista[1]
    id = lista[0]
    imc = round(peso/(estatura*estatura),2)
    diagnostico = clasificacion + "\t" + str(imc) + "\t" + str(id) + "\t" + str(peso) + "\t" + str(estatura) + "\t" 
    if lista[5]=="1":
      diagnostico = diagnostico + "\tDiabetes"
    else:
     diagnostico = diagnostico  + "\t--------"

    if lista[6]=="1":
      diagnostico = diagnostico + "\tHipertension"
    else:
     diagnostico = diagnostico  + "\t--------"
     if lista[7]=="1":
      diagnostico = diagnostico + "\tCorazón"
     else:
      diagnostico = diagnostico  + "\t--------"
    if lista[8]=="1":
      diagnostico = diagnostico + "\tCáncer"
      
    else:
     diagnostico = diagnostico  + "\t--------"
    if lista[9]=="1":
      diagnostico = diagnostico + "\tTabaquismo"
    else:
     diagnostico = diagnostico  + "\t--------"
    if lista[9]=="1":
      diagnostico = diagnostico + "\tCon Vacuna"
    else:
     diagnostico = diagnostico  + "\t--------"
    return (diagnostico)

# %%
def cambiardatos(empleados):
  for lista in empleados:
   print(mprimeempleado(lista))
      
  id = int(input("Indique el ID del empleado que desea actualizar"))
  nlista = []
  loencontro = 0
  posicion = 0
  cuenta = 0
  for lista in empleados:
    
    if lista[0]==str(id):
      loencontro = 1

      nlista.append(str(id))
      
      name=input("Nombre: " + lista[1])
      if len(str(name))!=0:
        nlista.append(name)
      else:
        nlista.append(lista[1])
      edad=input("Edad: " + lista[2])
      if len(str(edad))!=0:
        nlista.append(edad)
      else:
        nlista.append(lista[2])
      
      peso=input("Ingrese Peso(Kg): " + lista[3])
      if len(str(peso))!=0:
        nlista.append(peso)
      else:
        nlista.append(lista[3])

      
      estatura=input("Ingrese Estatura(mts): " +lista[4])
      if len(str(estatura))!=0:
        nlista.append(estatura)
      else:
        nlista.append(lista[4])

      
      diabe=input("Diabetes: 1.-Si 2.-No: " + lista[5])
      if len(str(diabe))!=0:
        nlista.append(diabe)
      else:
        nlista.append(lista[5])

      
      hiper=input("Hipertensión: 1.-Si 2.-No: " + lista[6])
      if len(str(hiper))!=0:
        nlista.append(hiper)
      else:
        nlista.append(lista[6])
      
      cora=input("Problema de Corazón: 1.-Si 2.-No: " + lista[7])
      if len(str(cora))!=0:
        nlista.append(cora)
      else:
        nlista.append(lista[7])
    
      
      cancer=input("Cancer: 1.-Si 2.-No: "  + lista[8])
      if len(str(cancer))!=0:
        nlista.append(cancer)
      else:
        nlista.append(lista[8])
      
      tabaquismo=input("Tabaquismo: 1.-Si 2.-No: "  + lista[9])
      if len(str(tabaquismo))!=0:
        nlista.append(tabaquismo)
      else:
        nlista.append(lista[9])

      
      vacuna=input("Vacuna Covid: 1.-Si 2.-No: "  + lista[10])
      if len(str(vacuna))!=0:
        nlista.append(vacuna)
      else:
        nlista.append(lista[10])
      

      departam=input("No de Departamento:"  + lista[11])
      if len(str(departam))!=0:
        nlista.append(departam)
      else:
        nlista.append(lista[11])

      posicion = cuenta

    cuenta = cuenta + 1

  if loencontro==1:  
    actualizar = input("¿Está seguro de que quiere actualizar los datos del empleado? Si/No ")
  
    
    if actualizar=="si":
      empleados.pop(posicion)
      #print(empleados)
      empleados.append(nlista)
      

      open('empleados2.txt', 'w').close()

      archivo = open("empleados2.txt", "w")
      for lista in empleados:
        #ImprimeEmpleado(lista)
        for palabra in lista:
          archivo.write(str(palabra) + ",")
        archivo.write("\n")
      archivo.close()

  else:
    print("El ID del empleado no se encontro")
  
      #if (actualizar="si")

  
    #if !loencontro:
     # print("No se encontro el ID del empleado")
      #return

# %%
def reporte(empleados):
  diabetes= 0
  hipertension= 0
  corazon= 0
  cancer= 0
  tabaquismo = 0 #Contadores
  vacuna_covid= 0
  
  contador_enfermedades = [0, 0, 0, 0, 0, 0]
  enfermedad = ["Diabetes", "Hipertensión", "Corazón", "Cáncer", "Tabaquismo", "Vacuna Covid"]
  print(f'{"ID":<10}{"Nombre":<15}{"Peso":<10}{"Altura":<10}{"Enfermedades":^77}{"Vacuna Covid":<12}')
  
  for lista in empleados:
    
   if diabetes == "1":
      contador_enfermedades[0] += 1
   if hipertension == "1":
      contador_enfermedades[1] += 1
   if corazon == "1":
      contador_enfermedades[2] += 1
   if cancer == "1":
      contador_enfermedades[3] += 1
   if tabaquismo == "1":
      contador_enfermedades[4] += 1
   if vacuna_covid == "1":
      contador_enfermedades[5] += 1
  print ("Empleados:" + str(len(empleados)) + "\n")
  print(f'{id:<10}{nombre:<15}{peso:<10}{altura:<10}{"Diabetes" if diabetes == "1" else "____________":15}{"Hipertensión" if hipertension == "1" else "____________":17}{"Corazón" if corazon == "1" else "____________":15}{"Cáncer" if cancer == "1" else "____________":15}{"Tabaquismo" if tabaquismo == "1" else "____________":15}{"Vacunado" if vacuna_covid == "1" else "____________":15}')
  
  print(f'\n{"Enfermedad":27}{"Cantidad":10}{"Porcentaje":<10}')

  lista = []
  for num in range(len(contador_enfermedades)):
    lista_temp = []
    lista_temp = [contador_enfermedades[num], enfermedad[num], round(contador_enfermedades[num] / len(empleados) * 100)]
    lista.append(lista_temp)
  
  lista.sort(reverse = True)

  for dato in lista:
    contador, enfermedad, porcentaje = dato
    print(f"{enfermedad:20} {contador:7} {porcentaje:10}%")

  print(f'{"Total de empleados:":<10} {len(empleados):<10}')

# %%
def consultar_empleado(empleados): #Función para seleccionar un empleado en especifico.
  id = int(input("Indique su ID: "))  #Solicita el id
  
  loencontro = 0
  posicion = 0 #contadores
  cuenta = 0
  for lista in empleados: # en la lista de empleados, buscara la ID, en el valor 0 que es el lugar donde se encuentra la ID.
    
    if lista[0]==str(id):
      loencontro = 1
      print(imprimeempleado(lista)) #Impime los datos de ese ID
      
  if lista[0] != str(id):
      print("No se encontro su ID")# Si no se encuentra, marca este texto.

# %%
def imprimeempleado(lista):
    peso  = float(lista[3])
    estatura = float(lista[4])
    nombre = lista[1]
    id = lista[0]
    imc = round(peso/(estatura*estatura),2)
    diagnostico = nombre + "\t" + str(imc) + "\t" + str(id) + "\t" + str(peso) + "\t" + str(estatura) + "\t" 
    if lista[5]=="1":
      diagnostico = diagnostico + "\tDiabetes"
    else:
     diagnostico = diagnostico  + "\t--------"

    if lista[6]=="1":
      diagnostico = diagnostico + "\tHipertension"
    else:
     diagnostico = diagnostico  + "\t--------"
     if lista[7]=="1":
      diagnostico = diagnostico + "\tCorazón"
     else:
      diagnostico = diagnostico  + "\t--------"
    if lista[8]=="1":
      diagnostico = diagnostico + "\tCáncer"
      
    else:
     diagnostico = diagnostico  + "\t--------"
    if lista[9]=="1":
      diagnostico = diagnostico + "\tTabaquismo"
    else:
     diagnostico = diagnostico  + "\t--------"
    if lista[9]=="1":
      diagnostico = diagnostico + "\tCon Vacuna"
    else:
     diagnostico = diagnostico  + "\t--------"
    return (diagnostico)
